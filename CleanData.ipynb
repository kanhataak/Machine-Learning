# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\MR.INDIA\Desktop\DataSets\datasets.csv")
df
# Out:
#    type                       name               y  \
# 0     r                abalone.csv           rings
# 1     r               auto-mpg.csv             mpg
# 2     r                   bupa.csv        selector
# 3     c                covtype.csv      cover_type
# 4     r                    crx.csv             a16
# 5     r            feature_eng.csv   ratio_poly-y0
# 6     r            feature_eng.csv   ratio_diff-y0
# 7     r            feature_eng.csv  ratio_poly2-y0
# 8     r            feature_eng.csv         sqrt-y0
# 9     r            feature_eng.csv          log-y0
# 10    r            feature_eng.csv        poly2-y0
# 11    r            feature_eng.csv         poly-y0
# 12    r            feature_eng.csv          pow-y0
# 13    r            feature_eng.csv         diff-y0
# 14    r            feature_eng.csv   coef_ratio-y0
# 15    r            feature_eng.csv        ratio-y0
# 16    c            forestfires.csv            area
# ...

# %%
df.isnull().sum()
# Out:
# type            0
# name            0
# y               0
# x              17
# experiments     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 5 columns):
# type           28 non-null object
# name           28 non-null object
# y              28 non-null object
# x              11 non-null object
# experiments    28 non-null object
# dtypes: object(5)
# memory usage: 624.0+ bytes
